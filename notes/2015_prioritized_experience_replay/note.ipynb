# %% [markdown]
# # Prioritized experience replay
# ### リファレンス
# [DQNの進化史 ③優先度付き経験再生, Multi-step learning, C51](https://horomary.hatenablog.com/entry/2021/02/09/235108)

# %%
import os
import sys
from pathlib import Path
import gymnasium as gym
import torch

current_dir = Path(os.getcwd())
notes_dir = current_dir.parent
target_path = notes_dir / '2013_deep_q_network/code'

# sys.path に追加
if str(target_path) not in sys.path:
    print(target_path)
    sys.path.append(str(target_path))

from catcher_observer import CatcherObserver

# %%
from code.double_dqn_agent import DoubleDqnAgent
from code.double_dqn_trainer import DoubleDqnTrainer

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
Training = False
print('device: ', device)
# Out:
# device:  mps

# %%
game = "BreakoutDeterministic-v4"

# 17787steps / 97min
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Done initialization. From now, begin training!
# episode: 1530, step_count: 3, sum_reward: 0.0, avg_loss: 0.04
# best model saved:  models/double_dqn_agent_best.pth
# episode: 1533, step_count: 58, sum_reward: 1.0, avg_loss: 0.03
# best model saved:  models/double_dqn_agent_best.pth
# episode: 1598, step_count: 25, sum_reward: 0.0, avg_loss: 0.01
# model saved:  models/double_dqn_agent_1598.pth
# episode: 1627, step_count: 170, sum_reward: 3.0, avg_loss: 0.01
# best model saved:  models/double_dqn_agent_best.pth
# episode: 1667, step_count: 154, sum_reward: 4.0, avg_loss: 0.01
# best model saved:  models/double_dqn_agent_best.pth
# episode: 4253, step_count: 25, sum_reward: 0.0, avg_loss: 0.0
# model saved:  models/double_dqn_agent_4253.pth
# episode: 4475, step_count: 25, sum_reward: 0.0, avg_loss: 0.0
# model saved:  models/double_dqn_agent_4475.pth
# episode: 5441, step_count: 25, sum_reward: 0.0, avg_loss: 0.0
# model saved:  models/double_dqn_agent_5441.pth
# episode: 6524, step_count: 209, sum_reward: 5.0, avg_loss: 0.0
# best model saved:  models/double_dqn_agent_best.pth
# episode: 6872, step_count: 27, sum_reward: 0.0, avg_loss: 0.0
# model saved:  models/double_dqn_agent_6872.pth
# episode: 7052, step_count: 73, sum_reward: 1.0, avg_loss: 0.0
# model saved:  models/double_dqn_agent_7052.pth
# episode: 7222, step_count: 25, sum_reward: 0.0, avg_loss: 0.0
# model saved:  models/double_dqn_agent_7222.pth
# ...
# episode: 17075, step_count: 53, sum_reward: 1.0, avg_loss: 0.01
# model saved:  models/double_dqn_agent_17075.pth
# episode: 17787, step_count: 378, sum_reward: 13.0, avg_loss: 0.01
# model saved:  models/double_dqn_agent_17787.pth

if Training:
    model_path = "models/double_dqn_agent.pth"
    trainer = DoubleDqnTrainer(model_path=model_path, device=device)
    env = gym.make(game, render_mode="rgb_array")
    obs = CatcherObserver(env, 84, 84, 4) # width, height, n_frame
    agent = trainer.train(env=obs)

# %%
model_path = "models/double_dqn_agent_best.pth"
env = gym.make(game)
obs = CatcherObserver(env, 84, 84, 4) # width, height, n_frame
agent = DoubleDqnAgent.load(actions=list(range(env.action_space.n)), model_path=model_path, device=device)
agent.play(obs, render=True)
# Out:
# 0: Get reward 5.0.
# 1: Get reward 5.0.
# 2: Get reward 5.0.
# 3: Get reward 5.0.
# 4: Get reward 5.0.
# 5: Get reward 5.0.
# 6: Get reward 5.0.
# 7: Get reward 5.0.
# 8: Get reward 5.0.
# 9: Get reward 5.0.
