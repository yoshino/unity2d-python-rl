# %% [markdown]
# # SAC: Soft Actor Critic
# ### リファレンス
# - [Ｐｙｔｈｏｎで学ぶ強化学習](https://www.amazon.co.jp/dp/B082HNNGQG/)
# - [Soft-Actor-Critic (SAC) ①Soft-Q学習からSACへ](https://horomary.hatenablog.com/entry/2020/12/20/115439)
# - [[論文解説] Soft Actor-Critic](https://qiita.com/ku2482/items/fb79d8209f1162d9f141)
# - [PyTorchを使って連続値制御の深層強化学習のSoft Actor Criticを構築する](https://www.dskomei.com/entry/2022/06/30/222228)
#
# ### code
# - [icoxfog417/baby-steps-of-rl-ja](https://github.com/icoxfog417/baby-steps-of-rl-ja)
# - [horoiwa/deep_reinforcement_learning_gallery](https://github.com/horoiwa/deep_reinforcement_learning_gallery/tree/master)
# - [dskomei/deep_reinforcement_learning/soft_actor_critic](https://github.com/dskomei/deep_reinforcement_learning/tree/main/soft_actor_critic)

# %%
import torch

from code.pendulum_observer import PendulumObserver
from code.sac_trainer import SACTrainer
from code.sac_agent import SACAgent

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print('device: ', device)
Training = True
# Out:
# device:  mps

# %% [markdown]
# ### Training

# %%
observer = PendulumObserver()
print(observer._env.action_space.high)
print(observer._env.action_space.sample())
# Out:
# [2.]
# [0.05300799]

# %%
if Training:
    observer = PendulumObserver()
    model_path = "models/sac_agent.pth"
    trainer = SACTrainer(model_path=model_path, device=device)
    agent = trainer.train(env=observer)
# Out:
# episode: 0, sum_reward: -1667.6105475884024
# Episode: 0, Eval Avg. Reward: -1467
# episode: 1, sum_reward: -1066.6559562850728
# episode: 2, sum_reward: -1535.8433342399494
# episode: 3, sum_reward: -1172.263737618276
# episode: 4, sum_reward: -1078.0742489910704
# episode: 5, sum_reward: -1480.1545374954803
# episode: 6, sum_reward: -1292.5228736538222
# episode: 7, sum_reward: -1442.3452067274316
# episode: 8, sum_reward: -1320.0874045898374
# episode: 9, sum_reward: -1286.0822455408627
# episode: 10, sum_reward: -947.3797422776476
# Episode: 10, Eval Avg. Reward: -1136
# episode: 11, sum_reward: -781.9340008799928
# episode: 12, sum_reward: -998.1819028499665
# episode: 13, sum_reward: -812.4189598826251
# episode: 14, sum_reward: -660.9321663814563
# episode: 15, sum_reward: -638.7301118706638
# episode: 16, sum_reward: -639.5981110369449
# episode: 17, sum_reward: -387.44474499836326
# episode: 18, sum_reward: -454.85128098591935
# episode: 19, sum_reward: -538.5282517612724
# episode: 20, sum_reward: -1080.670562121776
# Episode: 20, Eval Avg. Reward: -937
# episode: 21, sum_reward: -249.19447333734075
# episode: 22, sum_reward: -1086.637064476124
# episode: 23, sum_reward: -122.30965747046965
# episode: 24, sum_reward: -241.64660054077478
# episode: 25, sum_reward: -251.30036084950405
# episode: 26, sum_reward: -126.51057954754195
# episode: 27, sum_reward: -124.79336495143058
# episode: 28, sum_reward: -361.4379040315614
# episode: 29, sum_reward: -125.3851512772562
# episode: 30, sum_reward: -238.8240507569846
# Episode: 30, Eval Avg. Reward: -495
# episode: 31, sum_reward: -120.15636103517164
# episode: 32, sum_reward: -373.96804731389255
# episode: 33, sum_reward: -122.50435204995605
# episode: 34, sum_reward: -232.41429475461055
# episode: 35, sum_reward: -118.93139424687186
# episode: 36, sum_reward: -120.62661387690977
# episode: 37, sum_reward: -122.28782800672815
# episode: 38, sum_reward: -1453.3267473976307
# episode: 39, sum_reward: -2.7601895285766083
# best model saved:  models/sac_agent_best.pth
# episode: 40, sum_reward: -240.80349755307824
# Episode: 40, Eval Avg. Reward: -441
# episode: 41, sum_reward: -121.93073190459432
# episode: 42, sum_reward: -116.1312862268283
# episode: 43, sum_reward: -1362.3822705659552
# episode: 44, sum_reward: -1.842635120435868
# best model saved:  models/sac_agent_best.pth
# episode: 45, sum_reward: -248.0079987956586
# episode: 46, sum_reward: -122.5184391301418
# episode: 47, sum_reward: -119.76534624847923
# episode: 48, sum_reward: -122.35057580435503
# episode: 49, sum_reward: -319.0148066916747
# episode: 50, sum_reward: -0.7812449943892622
# best model saved:  models/sac_agent_best.pth
# Episode: 50, Eval Avg. Reward: -216
# episode: 51, sum_reward: -125.42545679400969
# episode: 52, sum_reward: -235.0703519429657
# episode: 53, sum_reward: -120.27068805291417
# episode: 54, sum_reward: -114.2199433812189
# episode: 55, sum_reward: -121.75293494414342
# episode: 56, sum_reward: -2.0515848711018605
# episode: 57, sum_reward: -371.89026327906157
# episode: 58, sum_reward: -126.65156480690443
# episode: 59, sum_reward: -122.86719526049832
# episode: 60, sum_reward: -246.5963223290629
# Episode: 60, Eval Avg. Reward: -148
# episode: 61, sum_reward: -119.77151714094059
# episode: 62, sum_reward: -3.0152448279144473
# episode: 63, sum_reward: -123.84366206126684
# episode: 64, sum_reward: -383.66372692333357
# episode: 65, sum_reward: -124.81409713720986
# episode: 66, sum_reward: -376.4264913742966
# episode: 67, sum_reward: -125.00057848676516
# episode: 68, sum_reward: -127.40880701463237
# episode: 69, sum_reward: -0.6012668038316251
# best model saved:  models/sac_agent_best.pth
# episode: 70, sum_reward: -120.59732818420872
# Episode: 70, Eval Avg. Reward: -184
# episode: 71, sum_reward: -126.59204930450247
# episode: 72, sum_reward: -126.03489719551024
# episode: 73, sum_reward: -114.47885801831077
# episode: 74, sum_reward: -116.78653134563571
# episode: 75, sum_reward: -126.12070530497527
# episode: 76, sum_reward: -254.36690051501424
# episode: 77, sum_reward: -122.60191556186557
# episode: 78, sum_reward: -0.9754396412509034
# episode: 79, sum_reward: -126.48607924568208
# episode: 80, sum_reward: -360.77123262127844
# Episode: 80, Eval Avg. Reward: -202
# episode: 81, sum_reward: -119.54365936246579
# episode: 82, sum_reward: -291.28241563499006
# episode: 83, sum_reward: -271.5692265264044
# episode: 84, sum_reward: -255.1584700725819
# episode: 85, sum_reward: -125.01535219703527
# episode: 86, sum_reward: -232.11269006753255
# episode: 87, sum_reward: -334.989079397246
# episode: 88, sum_reward: -1.1855314557205323
# episode: 89, sum_reward: -258.97784080413953
# episode: 90, sum_reward: -245.19808402392607
# Episode: 90, Eval Avg. Reward: -168
# episode: 91, sum_reward: -116.49101244274979
# episode: 92, sum_reward: -324.9739294254079
# episode: 93, sum_reward: -237.00839920819277
# episode: 94, sum_reward: -1.620670096771682
# episode: 95, sum_reward: -127.0881746324191
# episode: 96, sum_reward: -334.0981647717999
# episode: 97, sum_reward: -122.1537373305041
# episode: 98, sum_reward: -116.55054457223197
# episode: 99, sum_reward: -0.9069036734959222
# final model saved:  models/sac_agent_final.pth

# %% [markdown]
# ### Play

# %%
observer = PendulumObserver(play=True)
agent = SACAgent.load(state_dim=3, action_dim=1, action_bound=2.0, device=device, model_path="./models/sac_agent_final.pth")
agent.play(observer, render=True)
# Out:
# episode 0: -116.89608459864822
# /Users/yoshino/.pyenv/versions/3.11.4/lib/python3.11/site-packages/gymnasium/envs/classic_control/pendulum.py:173: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("Pendulum-v1", render_mode="rgb_array")
#   gym.logger.warn(
# episode 1: -121.14783541324779
# episode 2: -241.76147170184362
# episode 3: -239.91114541270076
# episode 4: -123.7203002577424
# episode 5: -0.7195734238558763
# episode 6: -125.01643038019061
# episode 7: -124.3689950989133
# episode 8: -0.6038374488802254
# episode 9: -122.63082685885757
